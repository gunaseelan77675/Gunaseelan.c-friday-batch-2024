# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.whttps://colab.research.google.com/drive/1hMy5zz4P8-HMlfXNH2-8Pu_S2-sretkX?authuser=3#scrollTo=DByxGg-LATYdalk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=[15,6]

# %%
df=pd.read_csv('/content/students_mental_health_survey.csv')
df.head()
# Out:
#    Age            Course  Gender  CGPA  Stress_Level  Depression_Score  \
# 0   25            Others    Male  3.56             3                 3
# 1   24       Engineering  Female  2.44             0                 3
# 2   19          Business  Female  3.74             4                 0
# 3   19  Computer Science    Male  3.65             2                 1
# 4   18          Business    Male  3.40             3                 3
#
#    Anxiety_Score Sleep_Quality Physical_Activity Diet_Quality Social_Support  \
# 0              2          Good          Moderate         Good       Moderate
# 1              0       Average               Low      Average            Low
# 2              3          Good               Low      Average       Moderate
# 3              0       Average               Low      Average       Moderate
# 4              4          Good               Low      Average           High
#
#   Relationship_Status Substance_Use Counseling_Service_Use Family_History  \
# 0             Married         Never                  Never             No
# 1              Single  Occasionally           Occasionally             No
# 2   In a Relationship         Never           Occasionally             No
# 3              Single           NaN                  Never             No
# 4             Married         Never                  Never             No
#
#   Chronic_Illness  Financial_Stress Extracurricular_Involvement  \
# 0              No                 2                    Moderate
# 1              No                 3                         Low
# 2              No                 4                        High
# 3              No                 4                    Moderate
# 4             Yes                 0                        High
#
#    Semester_Credit_Load Residence_Type
# 0                    17      On-Campus
# 1                    27      On-Campus
# 2                    15      On-Campus
# 3                    20     Off-Campus
# 4                    23      On-Campus

# %%
df.shape
# Out:
# (7022, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7022 entries, 0 to 7021
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          7022 non-null   int64
#  1   Course                       7022 non-null   object
#  2   Gender                       7022 non-null   object
#  3   CGPA                         7010 non-null   float64
#  4   Stress_Level                 7022 non-null   int64
#  5   Depression_Score             7022 non-null   int64
#  6   Anxiety_Score                7022 non-null   int64
#  7   Sleep_Quality                7022 non-null   object
#  8   Physical_Activity            7022 non-null   object
#  9   Diet_Quality                 7022 non-null   object
#  10  Social_Support               7022 non-null   object
#  11  Relationship_Status          7022 non-null   object
#  12  Substance_Use                7007 non-null   object
#  13  Counseling_Service_Use       7022 non-null   object
#  14  Family_History               7022 non-null   object
#  15  Chronic_Illness              7022 non-null   object
#  16  Financial_Stress             7022 non-null   int64
#  17  Extracurricular_Involvement  7022 non-null   object
#  18  Semester_Credit_Load         7022 non-null   int64
#  19  Residence_Type               7022 non-null   object
# dtypes: float64(1), int64(6), object(13)
# memory usage: 1.1+ MB

# %%
pr=5
c=5
it=1
for i,j in enumerate(df.columns):
    plt.subplot(r,c,it)
    if df[j].dtype=='object':
        sns.countplot(y=df[j])
    else:
        sns.kdeplot(df[j])
        plt.grid()
    it+=1
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Age            Course  Gender  CGPA  Stress_Level  Depression_Score  \
# 0   25            Others    Male  3.56             3                 3
# 1   24       Engineering  Female  2.44             0                 3
# 2   19          Business  Female  3.74             4                 0
# 3   19  Computer Science    Male  3.65             2                 1
# 4   18          Business    Male  3.40             3                 3
#
#    Anxiety_Score Sleep_Quality Physical_Activity Diet_Quality Social_Support  \
# 0              2          Good          Moderate         Good       Moderate
# 1              0       Average               Low      Average            Low
# 2              3          Good               Low      Average       Moderate
# 3              0       Average               Low      Average       Moderate
# 4              4          Good               Low      Average           High
#
#   Relationship_Status Substance_Use Counseling_Service_Use Family_History  \
# 0             Married         Never                  Never             No
# 1              Single  Occasionally           Occasionally             No
# 2   In a Relationship         Never           Occasionally             No
# 3              Single           NaN                  Never             No
# 4             Married         Never                  Never             No
#
#   Chronic_Illness  Financial_Stress Extracurricular_Involvement  \
# 0              No                 2                    Moderate
# 1              No                 3                         Low
# 2              No                 4                        High
# 3              No                 4                    Moderate
# 4             Yes                 0                        High
#
#    Semester_Credit_Load Residence_Type
# 0                    17      On-Campus
# 1                    27      On-Campus
# 2                    15      On-Campus
# 3                    20     Off-Campus
# 4                    23      On-Campus

# %%
df.isnull().sum()
# Out:
# Age                             0
# Course                          0
# Gender                          0
# CGPA                           12
# Stress_Level                    0
# Depression_Score                0
# Anxiety_Score                   0
# Sleep_Quality                   0
# Physical_Activity               0
# Diet_Quality                    0
# Social_Support                  0
# Relationship_Status             0
# Substance_Use                  15
# Counseling_Service_Use          0
# Family_History                  0
# Chronic_Illness                 0
# Financial_Stress                0
# Extracurricular_Involvement     0
# Semester_Credit_Load            0
# Residence_Type                  0
# dtype: int64

# %%
df=df.dropna()
df.head()
# Out:
#    Age       Course  Gender  CGPA  Stress_Level  Depression_Score  \
# 0   25       Others    Male  3.56             3                 3
# 1   24  Engineering  Female  2.44             0                 3
# 2   19     Business  Female  3.74             4                 0
# 4   18     Business    Male  3.40             3                 3
# 5   21      Medical  Female  3.35             2                 4
#
#    Anxiety_Score Sleep_Quality Physical_Activity Diet_Quality Social_Support  \
# 0              2          Good          Moderate         Good       Moderate
# 1              0       Average               Low      Average            Low
# 2              3          Good               Low      Average       Moderate
# 4              4          Good               Low      Average           High
# 5              3          Good          Moderate         Good           High
#
#   Relationship_Status Substance_Use Counseling_Service_Use Family_History  \
# 0             Married         Never                  Never             No
# 1              Single  Occasionally           Occasionally             No
# 2   In a Relationship         Never           Occasionally             No
# 4             Married         Never                  Never             No
# 5              Single         Never                  Never             No
#
#   Chronic_Illness  Financial_Stress Extracurricular_Involvement  \
# 0              No                 2                    Moderate
# 1              No                 3                         Low
# 2              No                 4                        High
# 4             Yes                 0                        High
# 5              No                 5                    Moderate
#
#    Semester_Credit_Load Residence_Type
# 0                    17      On-Campus
# 1                    27      On-Campus
# 2                    15      On-Campus
# 4                    23      On-Campus
# 5                    19     Off-Campus

# %%
df.shape
# Out:
# (6995, 20)

# %%
cat = df.select_dtypes(include='object')
cat.head()
# Out:
#         Course  Gender Sleep_Quality Physical_Activity Diet_Quality  \
# 0       Others    Male          Good          Moderate         Good
# 1  Engineering  Female       Average               Low      Average
# 2     Business  Female          Good               Low      Average
# 4     Business    Male          Good               Low      Average
# 5      Medical  Female          Good          Moderate         Good
#
#   Social_Support Relationship_Status Substance_Use Counseling_Service_Use  \
# 0       Moderate             Married         Never                  Never
# 1            Low              Single  Occasionally           Occasionally
# 2       Moderate   In a Relationship         Never           Occasionally
# 4           High             Married         Never                  Never
# 5           High              Single         Never                  Never
#
#   Family_History Chronic_Illness Extracurricular_Involvement Residence_Type
# 0             No              No                    Moderate      On-Campus
# 1             No              No                         Low      On-Campus
# 2             No              No                        High      On-Campus
# 4             No             Yes                        High      On-Campus
# 5             No              No                    Moderate     Off-Campus

# %%
for i in ['Family_History','Chronic_Illness']:
    cat[i] = cat[i].replace({'Yes':1,'No':0})

# %%
for i in ['Physical_Activity','Social_Support','Extracurricular_Involvement']:
    cat[i] = cat[i].replace({'Low':1,'Moderate':2,'High':3})

# %%
for i in ['Sleep_Quality','Diet_Quality']:
    cat[i] = cat[i].replace({'Poor':1,'Average':2,'Good':3})

# %%
for i in ['Substance_Use','Counseling_Service_Use']:
    cat[i] = cat[i].replace({'Never':0,'Occasionally':1,'Frequently':2})

# %%
cat['Course']=cat['Course'].map(cat['Course'].value_counts(normalize=True))
cat.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073    Male              3                  2             3
# 1  0.152538  Female              2                  1             2
# 2  0.102216  Female              3                  1             2
# 4  0.102216    Male              3                  1             2
# 5  0.299643  Female              3                  2             3
#
#    Social_Support Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0               2             Married              0                       0
# 1               1              Single              1                       1
# 2               2   In a Relationship              0                       1
# 4               3             Married              0                       0
# 5               3              Single              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement Residence_Type
# 0               0                0                            2      On-Campus
# 1               0                0                            1      On-Campus
# 2               0                0                            3      On-Campus
# 4               0                1                            3      On-Campus
# 5               0                0                            2     Off-Campus

# %%
cat['Gender'] = cat['Gender'].replace({'Male':1,'Female':0})
cat.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1              3                  2             3
# 1  0.152538       0              2                  1             2
# 2  0.102216       0              3                  1             2
# 4  0.102216       1              3                  1             2
# 5  0.299643       0              3                  2             3
#
#    Social_Support Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0               2             Married              0                       0
# 1               1              Single              1                       1
# 2               2   In a Relationship              0                       1
# 4               3             Married              0                       0
# 5               3              Single              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement Residence_Type
# 0               0                0                            2      On-Campus
# 1               0                0                            1      On-Campus
# 2               0                0                            3      On-Campus
# 4               0                1                            3      On-Campus
# 5               0                0                            2     Off-Campus

# %%
cat['Relationship_Status'].value_counts(normalize=True)
# Out:
# Relationship_Status
# Single               0.509221
# In a Relationship    0.295783
# Married              0.194996
# Name: proportion, dtype: float64

# %%
cat['Relationship_Status']=cat['Relationship_Status'].map(cat['Relationship_Status'].value_counts(normalize=True))
cat.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1              3                  2             3
# 1  0.152538       0              2                  1             2
# 2  0.102216       0              3                  1             2
# 4  0.102216       1              3                  1             2
# 5  0.299643       0              3                  2             3
#
#    Social_Support  Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0               2             0.194996              0                       0
# 1               1             0.509221              1                       1
# 2               2             0.295783              0                       1
# 4               3             0.194996              0                       0
# 5               3             0.509221              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement Residence_Type
# 0               0                0                            2      On-Campus
# 1               0                0                            1      On-Campus
# 2               0                0                            3      On-Campus
# 4               0                1                            3      On-Campus
# 5               0                0                            2     Off-Campus

# %%
cat['Residence_Type']=cat['Residence_Type'].map(cat['Residence_Type'].value_counts(normalize=True))
cat.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1              3                  2             3
# 1  0.152538       0              2                  1             2
# 2  0.102216       0              3                  1             2
# 4  0.102216       1              3                  1             2
# 5  0.299643       0              3                  2             3
#
#    Social_Support  Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0               2             0.194996              0                       0
# 1               1             0.509221              1                       1
# 2               2             0.295783              0                       1
# 4               3             0.194996              0                       0
# 5               3             0.509221              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement  \
# 0               0                0                            2
# 1               0                0                            1
# 2               0                0                            3
# 4               0                1                            3
# 5               0                0                            2
#
#    Residence_Type
# 0        0.401001
# 1        0.401001
# 2        0.401001
# 4        0.401001
# 5        0.396569

# %%
cat.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1              3                  2             3
# 1  0.152538       0              2                  1             2
# 2  0.102216       0              3                  1             2
# 4  0.102216       1              3                  1             2
# 5  0.299643       0              3                  2             3
#
#    Social_Support  Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0               2             0.194996              0                       0
# 1               1             0.509221              1                       1
# 2               2             0.295783              0                       1
# 4               3             0.194996              0                       0
# 5               3             0.509221              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement  \
# 0               0                0                            2
# 1               0                0                            1
# 2               0                0                            3
# 4               0                1                            3
# 5               0                0                            2
#
#    Residence_Type
# 0        0.401001
# 1        0.401001
# 2        0.401001
# 4        0.401001
# 5        0.396569

# %%
cat.boxplot()
# Out:
# <Axes: >

# %%
num = df.select_dtypes(include=np.number)
num.head()
# Out:
#    Age  CGPA  Stress_Level  Depression_Score  Anxiety_Score  Financial_Stress  \
# 0   25  3.56             3                 3              2                 2
# 1   24  2.44             0                 3              0                 3
# 2   19  3.74             4                 0              3                 4
# 4   18  3.40             3                 3              4                 0
# 5   21  3.35             2                 4              3                 5
#
#    Semester_Credit_Load
# 0                    17
# 1                    27
# 2                    15
# 4                    23
# 5                    19

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mmax = MinMaxScaler()

# %%
df=pd.concat([cat,num],axis=1)
df.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1              3                  2             3
# 1  0.152538       0              2                  1             2
# 2  0.102216       0              3                  1             2
# 4  0.102216       1              3                  1             2
# 5  0.299643       0              3                  2             3
#
#    Social_Support  Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0               2             0.194996              0                       0
# 1               1             0.509221              1                       1
# 2               2             0.295783              0                       1
# 4               3             0.194996              0                       0
# 5               3             0.509221              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement  \
# 0               0                0                            2
# 1               0                0                            1
# 2               0                0                            3
# 4               0                1                            3
# 5               0                0                            2
#
#    Residence_Type  Age  CGPA  Stress_Level  Depression_Score  Anxiety_Score  \
# 0        0.401001   25  3.56             3                 3              2
# 1        0.401001   24  2.44             0                 3              0
# 2        0.401001   19  3.74             4                 0              3
# 4        0.401001   18  3.40             3                 3              4
# 5        0.396569   21  3.35             2                 4              3
#
#    Financial_Stress  Semester_Credit_Load
# 0                 2                    17
# 1                 3                    27
# 2                 4                    15
# 4                 0                    23
# 5                 5                    19

# %%
df.columns
# Out:
# Index(['Course', 'Gender', 'Sleep_Quality', 'Physical_Activity',
#        'Diet_Quality', 'Social_Support', 'Relationship_Status',
#        'Substance_Use', 'Counseling_Service_Use', 'Family_History',
#        'Chronic_Illness', 'Extracurricular_Involvement', 'Residence_Type',
#        'Age', 'CGPA', 'Stress_Level', 'Depression_Score', 'Anxiety_Score',
#        'Financial_Stress', 'Semester_Credit_Load'],
#       dtype='object')

# %%
scale=['Sleep_Quality', 'Physical_Activity',
       'Diet_Quality', 'Social_Support','Extracurricular_Involvement','Age', 'CGPA', 'Stress_Level', 'Depression_Score', 'Anxiety_Score',
       'Financial_Stress', 'Semester_Credit_Load']

# %%
scale
# Out:
# ['Sleep_Quality',
#  'Physical_Activity',
#  'Diet_Quality',
#  'Social_Support',
#  'Extracurricular_Involvement',
#  'Age',
#  'CGPA',
#  'Stress_Level',
#  'Depression_Score',
#  'Anxiety_Score',
#  'Financial_Stress',
#  'Semester_Credit_Load']

# %%
df[scale] = mmax.fit_transform(df[scale])
df.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1            1.0                0.5           1.0
# 1  0.152538       0            0.5                0.0           0.5
# 2  0.102216       0            1.0                0.0           0.5
# 4  0.102216       1            1.0                0.0           0.5
# 5  0.299643       0            1.0                0.5           1.0
#
#    Social_Support  Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0             0.5             0.194996              0                       0
# 1             0.0             0.509221              1                       1
# 2             0.5             0.295783              0                       1
# 4             1.0             0.194996              0                       0
# 5             1.0             0.509221              0                       0
#
#    Family_History  Chronic_Illness  Extracurricular_Involvement  \
# 0               0                0                          0.5
# 1               0                0                          0.0
# 2               0                0                          1.0
# 4               0                1                          1.0
# 5               0                0                          0.5
#
#    Residence_Type       Age      CGPA  Stress_Level  Depression_Score  \
# 0        0.401001  0.411765  0.717949           0.6               0.6
# 1        0.401001  0.352941  0.000000           0.0               0.6
# 2        0.401001  0.058824  0.833333           0.8               0.0
# 4        0.401001  0.000000  0.615385           0.6               0.6
# 5        0.396569  0.176471  0.583333           0.4               0.8
#
#    Anxiety_Score  Financial_Stress  Semester_Credit_Load
# 0            0.4               0.4              0.142857
# 1            0.0               0.6              0.857143
# 2            0.6               0.8              0.000000
# 4            0.8               0.0              0.571429
# 5            0.6               1.0              0.285714

# %%
df.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
lim=15
for k in range(2,lim):
    kmeans = KMeans(n_clusters=k,random_state=42)
    model = kmeans.fit(df)
    wcss.append(model.inertia_)

# %%
wcss
# Out:
# [14633.365605505593,
#  13723.729996812417,
#  12976.887670892214,
#  11835.990139256097,
#  11527.634460912976,
#  11066.46539599901,
#  10671.935495193353,
#  10564.81735361962,
#  10539.541112485585,
#  10275.503906752996,
#  10074.040947709134,
#  9819.148812722511,
#  9682.917525801298]

# %%
plt.plot(range(2,lim),wcss)
plt.axvline(3,color='k')
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=3,random_state=42)
model = kmeans.fit(df)
model.labels_
# Out:
# array([0, 2, 2, ..., 2, 2, 0], dtype=int32)

# %%
df.shape[0]
# Out:
# 6995

# %%
df['clusters'] = pd.Series(model.labels_)
df.head()
# Out:
#      Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0  0.102073       1            1.0                0.5           1.0
# 1  0.152538       0            0.5                0.0           0.5
# 2  0.102216       0            1.0                0.0           0.5
# 4  0.102216       1            1.0                0.0           0.5
# 5  0.299643       0            1.0                0.5           1.0
#
#    Social_Support  Relationship_Status  Substance_Use  Counseling_Service_Use  \
# 0             0.5             0.194996              0                       0
# 1             0.0             0.509221              1                       1
# 2             0.5             0.295783              0                       1
# 4             1.0             0.194996              0                       0
# 5             1.0             0.509221              0                       0
#
#    Family_History  ...  Extracurricular_Involvement  Residence_Type       Age  \
# 0               0  ...                          0.5        0.401001  0.411765
# 1               0  ...                          0.0        0.401001  0.352941
# 2               0  ...                          1.0        0.401001  0.058824
# 4               0  ...                          1.0        0.401001  0.000000
# 5               0  ...                          0.5        0.396569  0.176471
#
#        CGPA  Stress_Level  Depression_Score  Anxiety_Score  Financial_Stress  \
# 0  0.717949           0.6               0.6            0.4               0.4
# 1  0.000000           0.0               0.6            0.0               0.6
# 2  0.833333           0.8               0.0            0.6               0.8
# 4  0.615385           0.6               0.6            0.8               0.0
# 5  0.583333           0.4               0.8            0.6               1.0
#
#    Semester_Credit_Load  clusters
# 0              0.142857       0.0
# 1              0.857143       2.0
# 2              0.000000       2.0
# 4              0.571429       0.0
# 5              0.285714       0.0
#
# [5 rows x 21 columns]

# %%
df
# Out:
#         Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0     0.102073       1            1.0                0.5           1.0
# 1     0.152538       0            0.5                0.0           0.5
# 2     0.102216       0            1.0                0.0           0.5
# 4     0.102216       1            1.0                0.0           0.5
# 5     0.299643       0            1.0                0.5           1.0
# ...        ...     ...            ...                ...           ...
# 7016  0.197427       0            0.5                0.0           0.5
# 7017  0.197427       0            1.0                0.0           0.0
# 7018  0.299643       0            1.0                0.5           0.5
# 7019  0.102073       1            1.0                1.0           0.0
# 7020  0.299643       1            0.5                1.0           0.0
#
#       Social_Support  Relationship_Status  Substance_Use  \
# 0                0.5             0.194996              0
# 1                0.0             0.509221              1
# 2                0.5             0.295783              0
# 4                1.0             0.194996              0
# 5                1.0             0.509221              0
# ...              ...                  ...            ...
# 7016             0.5             0.295783              0
# 7017             1.0             0.509221              0
# 7018             1.0             0.509221              0
# 7019             0.5             0.194996              0
# 7020             0.5             0.509221              0
#
#       Counseling_Service_Use  Family_History  ...  \
# 0                          0               0  ...
# 1                          1               0  ...
# 2                          1               0  ...
# 4                          0               0  ...
# 5                          0               0  ...
# ...                      ...             ...  ...
# 7016                       1               0  ...
# 7017                       2               1  ...
# 7018                       1               0  ...
# 7019                       1               0  ...
# 7020                       0               0  ...
#
#       Extracurricular_Involvement  Residence_Type       Age      CGPA  \
# 0                             0.5        0.401001  0.411765  0.717949
# 1                             0.0        0.401001  0.352941  0.000000
# 2                             1.0        0.401001  0.058824  0.833333
# 4                             1.0        0.401001  0.000000  0.615385
# 5                             0.5        0.396569  0.176471  0.583333
# ...                           ...             ...       ...       ...
# 7016                          0.5        0.396569  0.117647  0.570513
# 7017                          1.0        0.396569  0.117647  0.801282
# 7018                          0.0        0.396569  0.352941  0.826923
# 7019                          0.5        0.396569  0.470588  0.775641
# 7020                          0.5        0.396569  0.352941  0.775641
#
#       Stress_Level  Depression_Score  Anxiety_Score  Financial_Stress  \
# 0              0.6               0.6            0.4               0.4
# 1              0.0               0.6            0.0               0.6
# 2              0.8               0.0            0.6               0.8
# 4              0.6               0.6            0.8               0.0
# 5              0.4               0.8            0.6               1.0
# ...            ...               ...            ...               ...
# 7016           0.2               0.2            0.2               0.6
# 7017           0.6               0.2            1.0               0.2
# 7018           0.6               0.8            0.2               0.6
# 7019           0.8               1.0            0.2               0.8
# 7020           0.8               0.6            0.8               0.8
#
#       Semester_Credit_Load  clusters
# 0                 0.142857       0.0
# 1                 0.857143       2.0
# 2                 0.000000       2.0
# 4                 0.571429       0.0
# 5                 0.285714       0.0
# ...                    ...       ...
# 7016              1.000000       NaN
# 7017              0.785714       NaN
# 7018              0.000000       NaN
# 7019              0.142857       NaN
# 7020              0.214286       NaN
#
# [6995 rows x 21 columns]

# %%
df
# Out:
#         Course  Gender  Sleep_Quality  Physical_Activity  Diet_Quality  \
# 0     0.102073       1            1.0                0.5           1.0
# 1     0.152538       0            0.5                0.0           0.5
# 2     0.102216       0            1.0                0.0           0.5
# 4     0.102216       1            1.0                0.0           0.5
# 5     0.299643       0            1.0                0.5           1.0
# ...        ...     ...            ...                ...           ...
# 7016  0.197427       0            0.5                0.0           0.5
# 7017  0.197427       0            1.0                0.0           0.0
# 7018  0.299643       0            1.0                0.5           0.5
# 7019  0.102073       1            1.0                1.0           0.0
# 7020  0.299643       1            0.5                1.0           0.0
#
#       Social_Support  Relationship_Status  Substance_Use  \
# 0                0.5             0.194996              0
# 1                0.0             0.509221              1
# 2                0.5             0.295783              0
# 4                1.0             0.194996              0
# 5                1.0             0.509221              0
# ...              ...                  ...            ...
# 7016             0.5             0.295783              0
# 7017             1.0             0.509221              0
# 7018             1.0             0.509221              0
# 7019             0.5             0.194996              0
# 7020             0.5             0.509221              0
#
#       Counseling_Service_Use  Family_History  ...  \
# 0                          0               0  ...
# 1                          1               0  ...
# 2                          1               0  ...
# 4                          0               0  ...
# 5                          0               0  ...
# ...                      ...             ...  ...
# 7016                       1               0  ...
# 7017                       2               1  ...
# 7018                       1               0  ...
# 7019                       1               0  ...
# 7020                       0               0  ...
#
#       Extracurricular_Involvement  Residence_Type       Age      CGPA  \
# 0                             0.5        0.401001  0.411765  0.717949
# 1                             0.0        0.401001  0.352941  0.000000
# 2                             1.0        0.401001  0.058824  0.833333
# 4                             1.0        0.401001  0.000000  0.615385
# 5                             0.5        0.396569  0.176471  0.583333
# ...                           ...             ...       ...       ...
# 7016                          0.5        0.396569  0.117647  0.570513
# 7017                          1.0        0.396569  0.117647  0.801282
# 7018                          0.0        0.396569  0.352941  0.826923
# 7019                          0.5        0.396569  0.470588  0.775641
# 7020                          0.5        0.396569  0.352941  0.775641
#
#       Stress_Level  Depression_Score  Anxiety_Score  Financial_Stress  \
# 0              0.6               0.6            0.4               0.4
# 1              0.0               0.6            0.0               0.6
# 2              0.8               0.0            0.6               0.8
# 4              0.6               0.6            0.8               0.0
# 5              0.4               0.8            0.6               1.0
# ...            ...               ...            ...               ...
# 7016           0.2               0.2            0.2               0.6
# 7017           0.6               0.2            1.0               0.2
# 7018           0.6               0.8            0.2               0.6
# 7019           0.8               1.0            0.2               0.8
# 7020           0.8               0.6            0.8               0.8
#
#       Semester_Credit_Load  clusters
# 0                 0.142857       0.0
# 1                 0.857143       2.0
# 2                 0.000000       2.0
# 4                 0.571429       0.0
# 5                 0.285714       0.0
# ...                    ...       ...
# 7016              1.000000       NaN
# 7017              0.785714       NaN
# 7018              0.000000       NaN
# 7019              0.142857       NaN
# 7020              0.214286       NaN
#
# [6995 rows x 21 columns]

# %%
sns.countplot(x=df['clusters'])
plt.show()

# %%
sum(df['clusters'].value_counts().values)
# Out:
# 6973

# %%
from sklearn.metrics import silhouette_score

# %%
score = []
lim=15
for k in range(2,lim):
    kmeans = KMeans(n_clusters=k,random_state=42)
    label = kmeans.fit_predict(df.drop('clusters',axis=1))
    scores = silhouette_score(df.drop('clusters',axis=1),label)
    score.append(scores)

# %%
score
# Out:
# [0.151467146318334,
#  0.12129223452765647,
#  0.09332717274951609,
#  0.09516138996106226,
#  0.11043628606609596,
#  0.10804266793826293,
#  0.1155762954555014,
#  0.09508949303759483,
#  0.073235496874768,
#  0.07674630511458984,
#  0.07127677806170755,
#  0.08242671361354967,
#  0.08760356788231896]

# %%
score_df=pd.DataFrame({'clusters':range(2,lim),'score':score})
score_df[score_df['score']==score_df['score'].max()]
# Out:
#    clusters     score
# 0         2  0.151467
